# %% [markdown]
# # Chilean Wine

# %%
import pandas as pd

# %%
# create a sample dataframe
data = pd.read_json('Wine.json')
df = pd.DataFrame(data)

df.head()
# Out:
#    points                                              title  \
# 0      89       Caymus 1998 Cabernet Sauvignon (Napa Valley)
# 1      98   M. Chapoutier 1999 Le Méal Ermitage  (Hermitage)
# 2      97                         J.L. Chave 1999  Hermitage
# 3      96  Colgin 1999 Herb Lamb Vineyard Cabernet Sauvig...
# 4      96  Stag's Leap Wine Cellars 1998 SLV Cabernet Sau...
#
#                                          description taster_name  \
# 0  Creamy black cherry aromas layered with fresh ...        None
# 1  Chapoutier's selections of the best parcels of...  Roger Voss
# 2  Jean-Louis, the son of Gérard Chave, is now in...  Roger Voss
# 3  Aromas lean toward black cherry, chocolate and...        None
# 4  Certainly one of the successes of the vintage....        None
#
#   taster_twitter_handle  price         designation                variety  \
# 0                  None   70.0                None     Cabernet Sauvignon
# ...

# %%
# Show me the last 5 lines of the dataframe
df.tail()
# Out:
#       points                                              title  \
# 9995      89  Domaine Charles Frey 2016 Harmonie Pinot Noir ...
# 9996      89  Domaine Fernand Engel 2016 Pinot Noir Rosé (Al...
# 9997      89  Heartland 2014 Spice Trader Shiraz-Cabernet Sa...
# 9998      89  J. Scott Cellars 2016 Dry Grenache Rosé (Rogue...
# 9999      89  Baron Knyphausen 2015 Feinherb Riesling (Rhein...
#
#                                             description         taster_name  \
# 9995  A lick of vanilla precedes red berries on the ...    Anne Krebiehl MW
# 9996  Faint notes of red currant and rhubarb appear ...    Anne Krebiehl MW
# 9997  Mixed berries, cracked pepper and baking spice...      Joe Czerwinski
# 9998  A copper rose hue, this has a strong phenolic ...        Paul Gregutt
# 9999  Steely and sharp yet delicately sweet, this me...  Anna Lee C. Iijima
#
#      taster_twitter_handle  price   designation                    variety  \
# ...

# %%
df.sort_values(by='province')
# Out:
#       points                                              title  \
# 1471      83  A. Parparoussis 2005 Taos Dry Red Wine Red (Ac...
# 7621      90  Achaia Clauss 2015 Demestica Semi Dry Rosé (Ac...
# 1842      89  Errazuriz 2016 Max Reserva Sauvignon Blanc (Ac...
# 3213      86  Montes 2016 Classic Series Sauvignon Blanc (Ac...
# 3975      87  Montes 2015 Limited Selection Pinot Noir (Acon...
# ...      ...                                                ...
# 570       87                 Tsililis 2012 Theopetra Estate Red
# 722       89  Les Frères Dutruy 2014 Domaine de la Treille P...
# 5167      92  Neumeister 2016 Steirische Klassik Gelber Musk...
# 5715      92                               Psagot 2014 Peak Red
# 6170      86                      Mt. Beautiful 2014 Pinot Gris
#
#                                             description        taster_name  \
# 1471  Leather, spice, red fruit and smoke notes char...    Susan Kostrzewa
# ...

# %%
# Sort from most points to least
df.sort_values(by='points', ascending=False)
# Out:
#       points                                              title  \
# 7901      99  Venge 2008 Family Reserve Cabernet Sauvignon (...
# 9427      99  Chambers Rosewood Vineyards NV Rare Muscadelle...
# 9838      98      Quinta do Noval 2001 Nacional Vintage  (Port)
# 9837      98  Spottswoode 2013 Family Estate Grown Cabernet ...
# 9406      98  Kracher 2008 Zwischen den Seen Nummer 9 Trocke...
# ...      ...                                                ...
# 9331      80     Teillery 2014 Organic Carmenère (Maipo Valley)
# 3991      80                       Alfredo Roca 2006 Chardonnay
# 3990      80         Michael David 2005 Petite Petit Red (Lodi)
# 3989      80  Grgich Hills 2004 Miljenko's Old Vines Zinfand...
# 481       80  Catharine Valley 2005 Reserve Cabernet Franc (...
#
#                                             description        taster_name  \
# 7901  An absolute joy and triumph. Just superb, show...               None
# ...

# %%
df.sort_values(by='points', ascending=False).head(10)
# Out:
#       points                                              title  \
# 7901      99  Venge 2008 Family Reserve Cabernet Sauvignon (...
# 9427      99  Chambers Rosewood Vineyards NV Rare Muscadelle...
# 9838      98      Quinta do Noval 2001 Nacional Vintage  (Port)
# 9837      98  Spottswoode 2013 Family Estate Grown Cabernet ...
# 9406      98  Kracher 2008 Zwischen den Seen Nummer 9 Trocke...
# 9332      98  Williams Selyem 2013 Westside Road Neighbors P...
# 1         98   M. Chapoutier 1999 Le Méal Ermitage  (Hermitage)
# 9428      98  Pol Roger 2002 Cuvée Sir Winston Churchill Bru...
# 8646      97                      Masseto 2010 Merlot (Toscana)
# 2484      97  S.A. Prüm 2006 Wehlener Sonnenuhr Trockenbeere...
#
#                                             description         taster_name  \
# 7901  An absolute joy and triumph. Just superb, show...                None
# 9427  This wine is dark brown in hue with a greenish...      Joe Czerwinski
# ...

# %%
# Looking at gdp!
df.variety.nunique()
# Out:
# 338

# %%
df.variety.count()
# Out:
# 10000

# %%
# Sort by country and see who has wines with score over 90
df.sort_values(by='country', ascending=False)
df[df.points > 90]
# Out:
#       points                                              title  \
# 1         98   M. Chapoutier 1999 Le Méal Ermitage  (Hermitage)
# 2         97                         J.L. Chave 1999  Hermitage
# 3         96  Colgin 1999 Herb Lamb Vineyard Cabernet Sauvig...
# 4         96  Stag's Leap Wine Cellars 1998 SLV Cabernet Sau...
# 5         96            Dalla Valle 1999 Maya Red (Napa Valley)
# ...      ...                                                ...
# 9969      92  Salomon-Undhof 2015 Steinterrassen Riesling (K...
# 9970      92  Convento de Las Claras 2012 Heritage  (Ribera ...
# 9971      92  Château Grand Boise 2015 Rosé (Côtes de Proven...
# 9972      92     Domaine Marie Berenice 2013 Mourvèdre (Bandol)
# 9973      92             Elephant Hill 2014 Syrah (Hawke's Bay)
#
#                                             description        taster_name  \
# 1     Chapoutier's selections of the best parcels of...         Roger Voss
# ...

# %%
# Average points
df.points.median()
# Out:
# 88.0

# %%
# Times variety appears
df.variety.value_counts()
# Out:
# variety
# Pinot Noir                  1007
# Chardonnay                   930
# Cabernet Sauvignon           766
# Bordeaux-style Red Blend     630
# Red Blend                    624
#                             ...
# Picapoll                       1
# Cabernet Franc-Malbec          1
# Malvasia Istriana              1
# Colorino                       1
# Gamza                          1
# Name: count, Length: 338, dtype: int64

# %%
df.groupby(by='country').variety.value_counts()
# Out:
# country    variety
# Argentina  Malbec                  120
#            Cabernet Sauvignon       43
#            Chardonnay               29
#            Torrontés                19
#            Red Blend                18
#                                   ...
# US         Merlot-Petite Verdot      1
#            Kerner                    1
# Ukraine    Sparkling Blend           1
#            Chardonnay                1
# Uruguay    Tannat                    3
# Name: count, Length: 657, dtype: int64

# %%
varibycountry = df.groupby(by='country').variety.value_counts()

# %%
df.drop(columns=['taster_twitter_handle','taster_name', 'designation'],inplace=True)
df.keys()
# Out:
# Index(['points', 'title', 'description', 'price', 'variety', 'region_1',
#        'region_2', 'province', 'country', 'winery'],
#       dtype='object')

# %%
chwines = df[df["country"].str.contains("Lebanon|Serbia|Turkey|Slovenia|Ukraine|Uruguay|Romania|Mexico|Moldova|Brazil|Canada|Croatia|England|Georgia|Greece|India|Israel|Czech Republic|South Africa|Portugal|Austria|France|US|Germany|Italy|China|Australia|New Zealand|Bulgaria|Hungary|Spain|Argentina") == False]
  
print(chwines[['country']])
# Out:
#      country
# 22     Chile
# 26     Chile
# 31     Chile
# 116    Chile
# 222    Chile
# ...      ...
# 9833   Chile
# 9834   Chile
# 9835   Chile
# 9836   Chile
# 9876   Chile
#
# [362 rows x 1 columns]

# %%
#make new csv only for chile
chwines.to_csv("ch_wines.csv")
chwines.keys()
# Out:
# Index(['points', 'title', 'description', 'price', 'variety', 'region_1',
#        'region_2', 'province', 'country', 'winery'],
#       dtype='object')

# %%
chwines = pd.read_csv("ch_wines.csv")
chwines.head()
# Out:
#    Unnamed: 0  points                                              title  \
# 0          22      90  Montes 2010 Limited Selection Sauvignon Blanc ...
# 1          26      90  Kingston Family 2009 Alazan Pinot Noir (Casabl...
# 2          31      90  Errazuriz 2008 The Blend Limited Edition Red (...
# 3         116      90  Viña Maipo 2010 Limited Edition Syrah (Maipo V...
# 4         222      86        Tololo 2013 Sauvignon Blanc (Curicó Valley)
#
#                                          description  price          variety  \
# 0  This SB has one of Chile's best track records ...   15.0  Sauvignon Blanc
# 1  Always at the top of the Chilean Pinot heap is...   30.0       Pinot Noir
# 2  Alluring on the nose, with a ton of dried spic...   35.0        Red Blend
# 3  Strong, dark aromas of blackberry and cassis a...   33.0            Syrah
# 4  With grapefruit and orange aromas, this is on ...   10.0  Sauvignon Blanc
#
# ...

# %%
chwines.sort_values(by='variety', ascending=False)
chwines.variety.value_counts()
# Out:
# variety
# Cabernet Sauvignon                   60
# Sauvignon Blanc                      57
# Chardonnay                           43
# Carmenère                            34
# Pinot Noir                           30
# Red Blend                            26
# Merlot                               21
# Syrah                                21
# Malbec                               17
# White Blend                           7
# Carignan                              7
# Cabernet Sauvignon-Carmenère          6
# Rosé                                  4
# Sparkling Blend                       3
# Cabernet Franc                        3
# Bordeaux-style Red Blend              3
# Riesling                              2
# Cabernet Sauvignon-Merlot             2
# Cabernet Blend                        2
# Carmenère-Syrah                       1
# Sauvignon Gris                        1
# Chardonnay-Viognier                   1
# Mourvèdre                             1
# ...

# %%
chwines.province.value_counts()
# Out:
# province
# Colchagua Valley              57
# Casablanca Valley             52
# Maipo Valley                  50
# Maule Valley                  45
# Central Valley                28
# Leyda Valley                  22
# Cachapoal Valley              19
# Curicó Valley                 19
# Rapel Valley                  11
# Chile                          7
# Aconcagua Valley               7
# Lolol Valley                   7
# San Antonio                    5
# Limarí Valley                  5
# Aconcagua Costa                4
# Elqui Valley                   3
# Peumo                          3
# Puente Alto                    3
# Loncomilla Valley              3
# Lontué Valley                  2
# Bío Bío Valley                 1
# Sagrada Familia                1
# Itata Valley                   1
# Colchagua Costa                1
# Pirque                         1
# Buin                           1
# Marchigue                      1
# Apalta                         1
# ...

# %%
chwines.sort_values(by='province', ascending=False)
chwines.variety.value_counts()
# Out:
# variety
# Cabernet Sauvignon                   60
# Sauvignon Blanc                      57
# Chardonnay                           43
# Carmenère                            34
# Pinot Noir                           30
# Red Blend                            26
# Merlot                               21
# Syrah                                21
# Malbec                               17
# White Blend                           7
# Carignan                              7
# Cabernet Sauvignon-Carmenère          6
# Rosé                                  4
# Sparkling Blend                       3
# Cabernet Franc                        3
# Bordeaux-style Red Blend              3
# Riesling                              2
# Cabernet Sauvignon-Merlot             2
# Cabernet Blend                        2
# Carmenère-Syrah                       1
# Sauvignon Gris                        1
# Chardonnay-Viognier                   1
# Mourvèdre                             1
# ...

# %%
chwines.sort_values(by='province')
chwines.groupby(by='province').variety.value_counts()
# Out:
# province          variety
# Aconcagua Costa   Sauvignon Blanc             3
#                   Pinot Noir                  1
# Aconcagua Valley  Red Blend                   3
#                   Syrah                       1
#                   Petit Verdot                1
#                                              ..
# San Antonio       Syrah                       2
#                   Chardonnay                  1
#                   Pinot Noir                  1
#                   Sparkling Blend             1
# Santa Cruz        Bordeaux-style Red Blend    1
# Name: count, Length: 138, dtype: int64

# %%
chwines.groupby(by='variety').province.value_counts()
# Out:
# variety                   province
# Bordeaux-style Red Blend  Maipo Valley         1
#                           Santa Cruz           1
#                           Maule Valley         1
# Cabernet Blend            Maule Valley         1
#                           Colchagua Valley     1
#                                               ..
# White Blend               Lolol Valley         2
#                           Colchagua Valley     2
#                           Casablanca Valley    1
#                           Leyda Valley         1
#                           Maule Valley         1
# Name: count, Length: 138, dtype: int64

# %%
df.plot(x='variety', y='points', kind='scatter')
# Out:
# <Axes: xlabel='variety', ylabel='points'>

# %%
df.groupby(by='province') \
    .points \
    .median() \
    .sort_values() \
    .plot(kind='barh')
# Out:
# <Axes: ylabel='province'>
